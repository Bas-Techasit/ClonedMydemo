# %% [markdown]
# <a href="https://colab.research.google.com/github/Bas-Techasit/ClonedMydemo/blob/main/filters_cat.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Filters

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd "/content/drive/MyDrive/ClonedMydemo"
# Out:
# /content/drive/MyDrive/ClonedMydemo

# %%
#required library
import numpy as np
import cv2
from matplotlib import pyplot as plt
from PIL import Image
# %matplotlib inline

# %% [markdown]
# ## Linear filter

# %% [markdown]
# ### Blur filter (box)

# %% [markdown]
# #### Color image

# %%
image = cv2.imread('/content/drive/MyDrive/ClonedMydemo/cat.jpg') #read image
image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV) #convert to HSV

# %%
#Blur filter
kernel = np.ones((5,5),np.float32)/25
blur = cv2.filter2D(image,-1,kernel) #cv2.blur()

# %%
#Visualization
plt.figure(figsize=(22,12))

plt.subplot(121)
plt.imshow(cv2.cvtColor(image,cv2.COLOR_HSV2RGB))
plt.title('Original')

plt.subplot(122)
plt.imshow(cv2.cvtColor(blur, cv2.COLOR_HSV2RGB))
plt.title('Blur filter')
plt.show()

# %% [markdown]
# #### Graysclae image

# %%
image2 = cv2.cvtColor(image, cv2.COLOR_HSV2BGR)
image2 = cv2.cvtColor(image2, cv2.COLOR_BGR2GRAY) #convert to graysclae image

# %%
#Box filter
kernel = np.ones((15,15),np.float32)/225 #np.ones((5,5),np.float32)/25
blur = cv2.filter2D(image2,-1,kernel)

# %%
#Visualization
plt.figure(figsize=(22,12))

plt.subplot(121)
plt.imshow(image2, cmap='gray')
plt.title('Original')

plt.subplot(122)
plt.imshow(blur, cmap='gray')
plt.title('Blur filter')
plt.show()

# %% [markdown]
# ### Gauss filter

# %%
blur_gauss = cv2.GaussianBlur(image2,(9,9),21) #21

# %%
#Visualization
plt.figure(figsize=(22,12))

plt.subplot(121)
plt.imshow(image2, cmap='gray')
plt.title('Original')

plt.subplot(122)
plt.imshow(blur_gauss, cmap='gray')
plt.title('Gauss filter')
plt.show()

# %% [markdown]
# ### Laplace filter

# %%
edge_laplace = cv2.Laplacian(image2, 0, (5,5)) #24

# %%
#Visualization
plt.figure(figsize=(22,12))

plt.subplot(121)
plt.imshow(image2, cmap='gray')
plt.title('Original')

plt.subplot(122)
plt.imshow(edge_laplace, cmap='gray')
plt.title('Laplace filter')
plt.show()

# %% [markdown]
# ### Sobel

# %%
img = cv2.imread('/content/drive/MyDrive/ClonedMydemo/cat.jpg',0)

#https://opencv-python-tutroals.readthedocs.io/en/latest/py_tutorials/py_imgproc/py_gradients/py_gradients.html
# Output dtype = cv2.CV_8U
sobelx8u = cv2.Sobel(img,cv2.CV_8U,1,0,ksize=5)

laplacian = cv2.Laplacian(img,cv2.CV_64F)
sobelx = cv2.Sobel(img,cv2.CV_64F,1,0,ksize=5)
sobely = cv2.Sobel(img,cv2.CV_64F,0,1,ksize=5)

# %%
plt.figure(figsize=(22,22))

plt.subplot(2,2,1),plt.imshow(img,cmap = 'gray')
plt.title('Original'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,2),plt.imshow(laplacian,cmap = 'gray')
plt.title('Laplacian'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,3),plt.imshow(sobelx,cmap = 'gray')
plt.title('Sobel X'), plt.xticks([]), plt.yticks([])
plt.subplot(2,2,4),plt.imshow(sobely,cmap = 'gray')
plt.title('Sobel Y'), plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# ## Non-linear filter

# %% [markdown]
# ### Median filter

# %%
img = cv2.imread('/content/drive/MyDrive/ClonedMydemo/cat.jpg',0)

# %%
blur_median = cv2.medianBlur(img, 9)

# %%
plt.figure(figsize=(22,6))

plt.subplot(121)
plt.imshow(img, cmap='gray')
plt.title('Original')

plt.subplot(122)
plt.imshow(blur_median, cmap='gray')
plt.title('Median filter')
plt.show()
